# %% [markdown]
# ## Дополнительная практика ЛР 1
#
# LR1-P01.
#
# ## Мини-эксперимент "Mini Corpus"

# %%
#LR1-P02.
project_title = "Mini Corpus"

# %%
#LR1-P03
print(project_title)
# Out:
# Mini Corpus

# %% [markdown]
# ##LR1-P04
# ОШИБКА: После перезапуска runtime ячейка print(project_title) не работает до повторного запуска 1 ячейки, так как значение переменной удалилось после перезапуска.

# %% [markdown]
# ## LR1-P05 Что я проверил
# что было проверено:
# - как runtime воспринимает исходные переменные после перезапуска
# - переменная создается в отдельной кодовой ячейке
# - чтобы восстановить порядок runtime после перезапуск, можно повторно запустить ячейки поочереди сверху вниз

# %% [markdown]
# # LR1-P06
#
# ноутбук скачан в формате .ipynb с именем LR1-P_фипл_1 курс_1 группа_МАРКИН.ipynb

# %% [markdown]
# ## LR1-P07
# После выполнения очищения выводов сами коды не удаляются потому, что эта функция удаляет только данные, которые мы выводим с помощью функций (аутпуты)

# %% [markdown]
# ##LR1-P08
# ОБЫЧНЫЙ ТЕСТ:
# 1. выполняем restart
# 2. первая ячейка - project.title "Mini Corpus"
# вторая ячейка - print(project.title)
# 3. Запускаем сначала первую, потом вторую, получаем output Mini Corpus
#
# ТЕСТ С ОШИБКОЙ:
# 1. выполняем restart
# 2. первая ячейка - project.title "Mini Corpus"
# вторая ячейка - print(project.title)
# 3. запускаем вторую ячейку, получаем Name Error

# %% [markdown]
#  # LP1-P09
#
# Порядок в фалйе broken_cells.txt:
# 1) print(project_title)
# 2) project_title = "Text Lab"
# 3) project_title.upper()
#
# ИСПРАВЛЯЕМ:

# %%
project_title = "Text Lab"
print(project_title)
project_title.upper()
# Out:
# Text Lab
# 'TEXT LAB'

# %% [markdown]
# # LP1-P10
#
# Правило: когда нужно использовать restart/runn all?
# - Используем restart/run all тогда, когда нужно убедиться, что ноутбук не содержит случайно сохраненных состояний в runtime.

# %% [markdown]
# # LP1-PX
#
# Два способа восстановления после ошибки порядка ячеек:
#
# 1. вручную перезапустить ячейку
# 2. выполнить restart и run all
#
# - способ 2 более безопасный для новичка, потому что показывает, есть ли в ноутбуке случайное состояние runtime
