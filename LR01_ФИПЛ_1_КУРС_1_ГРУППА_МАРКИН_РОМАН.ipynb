# %% [markdown]
# # Лабораторная работа №1: Colab/Lupyter: ячейки, markdown, runtime, порядок выполнения и сохранение
#
# (выполнил Маркин Р.)

# %% [markdown]
# # ЛР 1. Colab/Jupyter
# Цель: восстановить порядок ячеек и проверить notebook после перезапуска.

# %% [markdown]
# ## БАЗОВЫЙ УРОВЕНЬ
# Сначала выполните ячейку с print до создания переменной и зафиксируйте ошибку.
#
# ПОЯСНЕНИЕ: ошибка NameError: name 'project_title' is not defined. Такая ошибка появляется потому, что переменная project_title еще не создана в runtime.

# %%
project_title = "Corpus Mini Lab"

# %%
print(project_title)
# Out:
# Corpus Mini Lab

# %% [markdown]
# ## Исправление
# Переставьте/запустите ячейки в правильном порядке. Заполните таблицу состояния в пособии.
#
# ПОЯСНЕНИЕ: Исправление ситуации: чтобы ячейки запустились без ошибок, меняем 1 и 2 ячейки местами, а затем запускаем их сверху вниз. В результате получаем корректное отображение значения переменной (текста).
#
# ТАБЛИЦА СОСТОЯНИЯ:
# 1. project_title = "Corpus Mini Lab"
#
# Что изменилось в runtime:
# - создана новая переменная со значением Corpus Mini Lab
#
# Вывод:
# - информации в выводе нет
#
# 2. print(project_title)
#
# Что изменилось в runtime:
# - ничего не изменилось
#
# Вывод:
# - выводится текст Corpus Mini Lab

# %% [markdown]
# ## СРЕДНИЙ УРОВЕНЬ
# Создайте Markdown-пояснение, кодовую ячейку и один тест Run all.

# %%
project_name = "OMG"
print(project_name)
# Out:
# OMG

# %% [markdown]
# ПОЯСНЕНИЕ: задаем значение переменной project_name, затем выводим его с помощью print. После run all все отображается корректно

# %% [markdown]
# # Таблица состояния
#
# 1. project_name = "OMG"
#
# Что изменилось в runtime:
#
# - создана новая переменная со значением 'OMG'
#
# Вывод:
#
# - информации в выводе нет
#
# 2. print(project_name)
#
# Что изменилось в runtime:
#
# - ничего
#
# Вывод:
#
# - выводится текст 'OMG'

# %% [markdown]
# # Как проверить
#
# 1. Нажимаем Restart session
# 2. Нажимаем Run All

# %% [markdown]
# # version note (после домашней работы, базовый уровень)
# v1. создание титульного markdown
# v2. добавление таблицы состояния по среднему уровню лабораторной
# v3. добавление раздела "Как проверить"

# %% [markdown]
# # Работа с mini_corpus.tsv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
